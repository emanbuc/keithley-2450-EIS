# %%
import matplotlib.pyplot as plt
import pandas

# %%
url = "../data/step-sine-RC-load-readback-100ms/generatedCurrentLevel_0.1.csv"
df_generated = pandas.read_csv(url, delimiter=";", header=None, names=["sample","value"])


print(df_generated)
# Out:
#      sample     value
# 0         1  0.000073
# 1         2  0.000135
# 2         3  0.000197
# 3         4  0.000258
# 4         5  0.000319
# ..      ...       ...
# 994     995 -0.000299
# 995     996 -0.000239
# 996     997 -0.000178
# 997     998 -0.000115
# 998     999 -0.000053
#
# [999 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_generated.value,marker = '.')

# %%
url_sweep_test_RC = "../data/step-sine-RC-load-readback-100ms/test_RC_load_readback_100ms_0.1.csv"
df_sweep_test_RC = pandas.read_csv(url_sweep_test_RC, delimiter=";")
print(df_sweep_test_RC)
# Out:
#                          Timestamp   Current   Voltage
# 0    02/09/2021 22:56:47.579354420  0.000073  0.072777
# 1    02/09/2021 22:56:47.759579980  0.000135  0.135094
# 2    02/09/2021 22:56:47.862035360  0.000197  0.197060
# 3    02/09/2021 22:56:47.964462380  0.000258  0.258572
# 4    02/09/2021 22:56:48.066919400  0.000319  0.318584
# ..                             ...       ...       ...
# 994  02/09/2021 22:58:35.422083720 -0.000300 -0.299507
# 995  02/09/2021 22:58:35.524514960 -0.000239 -0.239033
# 996  02/09/2021 22:58:35.626958740 -0.000178 -0.177521
# 997  02/09/2021 22:58:35.729399380 -0.000115 -0.115318
# 998  02/09/2021 22:58:35.909607860 -0.000053 -0.053116
#
# [999 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_sweep_test_RC.Timestamp,df_sweep_test_RC.Current,marker = '.')

# %%
plt.plot(df_sweep_test_RC.Voltage ,marker = '.')
