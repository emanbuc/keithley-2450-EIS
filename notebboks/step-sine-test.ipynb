# %%
import matplotlib.pyplot as plt
import pandas

# %%
url = "../data/step-sine-test/generatedCurrentLevel_1.csv"
df_generated = pandas.read_csv(url, delimiter=";", header=None, names=["sample","value"])


print(df_generated)
# Out:
#      sample     value
# 0         1  0.000063
# 1         2  0.000125
# 2         3  0.000187
# 3         4  0.000249
# 4         5  0.000309
# ..      ...       ...
# 994     995 -0.000309
# 995     996 -0.000249
# 996     997 -0.000187
# 997     998 -0.000125
# 998     999 -0.000063
#
# [999 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_generated.value,marker = '.')

# %%
url_sweep_test_RC = "../data/step-sine-test/test_RC_load_1.csv"
df_sweep_test_RC = pandas.read_csv(url_sweep_test_RC, delimiter=";")
print(df_sweep_test_RC)
# Out:
#                          Timestamp   Current   Voltage
# 0    02/09/2021 07:34:19.461376620  0.000063  0.062542
# 1    02/09/2021 07:34:19.551612780  0.000125  0.125088
# 2    02/09/2021 07:34:19.564079860  0.000187  0.187054
# 3    02/09/2021 07:34:19.576508160  0.000249  0.248447
# 4    02/09/2021 07:34:19.588928060  0.000309  0.308807
# ..                             ...       ...       ...
# 994  02/09/2021 07:34:40.640602820 -0.000309 -0.309280
# 995  02/09/2021 07:34:40.653038420 -0.000249 -0.249031
# 996  02/09/2021 07:34:40.665461320 -0.000187 -0.187752
# 997  02/09/2021 07:34:40.677882680 -0.000125 -0.125668
# 998  02/09/2021 07:34:40.768052640 -0.000063 -0.062889
#
# [999 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_sweep_test_RC.Current,marker = '.')

# %%
plt.plot(df_sweep_test_RC.Voltage ,marker = '.')
