# %%
import matplotlib.pyplot as plt
import pandas

# %%
url = "../data/step-sine-RC/generatedCurrentLevel_0.1.csv"
df_generated = pandas.read_csv(url, delimiter=";", header=None, names=["sample","value"])


print(df_generated)
# Out:
#       sample     value
# 0          1  0.000628
# 1          2  0.001253
# 2          3  0.001874
# 3          4  0.002487
# 4          5  0.003090
# ...      ...       ...
# 9994    9995 -0.003090
# 9995    9996 -0.002487
# 9996    9997 -0.001874
# 9997    9998 -0.001253
# 9998    9999 -0.000628
#
# [9999 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_generated.value,marker = '.')

# %%
url_sweep_test_RC = "../data/step-sine-RC/test_RC_load_0.1.csv"
df_sweep_test_RC = pandas.read_csv(url_sweep_test_RC, delimiter=";")
print(df_sweep_test_RC)
# Out:
#                           Timestamp   Current   Voltage
# 0     02/09/2021 16:19:23.866340060  0.000628  0.627548
# 1     02/09/2021 16:19:23.956558340  0.001254  1.253600
# 2     02/09/2021 16:19:23.969000740  0.001874  1.873790
# 3     02/09/2021 16:19:23.981438180  0.002487  2.486850
# 4     02/09/2021 16:19:23.993861780  0.003090  3.090150
# ...                             ...       ...       ...
# 9994  02/09/2021 16:22:59.764076400 -0.003090 -3.089450
# 9995  02/09/2021 16:22:59.776513660 -0.002487 -2.487180
# 9996  02/09/2021 16:22:59.788940080 -0.001874 -1.874550
# 9997  02/09/2021 16:22:59.801372160 -0.001253 -1.254220
# 9998  02/09/2021 16:22:59.891541140 -0.000628 -0.627800
#
# [9999 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_sweep_test_RC.Timestamp,df_sweep_test_RC.Current,marker = '.')

# %%
plt.plot(df_sweep_test_RC.Voltage ,marker = '.')
